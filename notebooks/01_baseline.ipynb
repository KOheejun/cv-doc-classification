# %% [markdown]
# # **📄 Document type classification baseline code**
# > 문서 타입 분류 대회에 오신 여러분 환영합니다! 🎉
# > 아래 baseline에서는 ResNet 모델을 로드하여, 모델을 학습 및 예측 파일 생성하는 프로세스에 대해 알아보겠습니다.
#
# ## Contents
# - Prepare Environments
# - Import Library & Define Functions
# - Hyper-parameters
# - Load Data
# - Train Model
# - Inference & Save File

# %% [markdown]
# ## 1. Prepare Environments
#
# * 데이터 로드를 위한 구글 드라이브를 마운트합니다.
# * 필요한 라이브러리를 설치합니다.

# %%
# 구글 드라이브 마운트, Colab을 이용하지 않는다면 패스해도 됩니다.
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
drive.mount('/content/drive')
# Out:
# Mounted at /gdrive
# Mounted at /content/drive

# %%
# 구글 드라이브에 업로드된 대회 데이터를 압축 해제하고 로컬에 저장합니다.
# !tar -xvf drive/MyDrive/datasets_fin.tar > /dev/null

# %%
# 필요한 라이브러리를 설치합니다.
# !pip install timm
# Out:
# Requirement already satisfied: timm in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (0.9.12)
# Requirement already satisfied: torch>=1.7 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from timm) (2.10.0)
# Requirement already satisfied: torchvision in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from timm) (0.25.0)
# Requirement already satisfied: pyyaml in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface-hub in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from timm) (1.4.1)
# Requirement already satisfied: safetensors in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from timm) (0.7.0)
# Requirement already satisfied: filelock in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torch>=1.7->timm) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=1.7->timm) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.7->timm) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (26.0)
# Requirement already satisfied: shellingham in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (4.67.3)
# Requirement already satisfied: typer-slim in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from huggingface-hub->timm) (0.24.0)
# Requirement already satisfied: anyio in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub->timm) (4.12.1)
# Requirement already satisfied: certifi in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub->timm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub->timm) (1.0.9)
# Requirement already satisfied: idna in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub->timm) (3.11)
# Requirement already satisfied: h11>=0.16 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->timm) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub->timm) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from jinja2->torch>=1.7->timm) (3.0.3)
# Requirement already satisfied: numpy in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torchvision->timm) (1.26.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: typer>=0.24.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from typer-slim->huggingface-hub->timm) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub->timm) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub->timm) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub->timm) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub->timm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub->timm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /root/ai-22-cv-cv-team2/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub->timm) (0.1.2)

# %% [markdown]
# ## 2. Import Library & Define Functions
# * 학습 및 추론에 필요한 라이브러리를 로드합니다.
# * 학습 및 추론에 필요한 함수와 클래스를 정의합니다.

# %%
import os
import time
import random

import timm
import torch
import albumentations as A
import pandas as pd
import numpy as np
import torch.nn as nn
from albumentations.pytorch import ToTensorV2
from torch.optim import Adam
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score
import wandb

# %%
# 시드를 고정합니다.
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# %%
# 데이터셋 클래스를 정의합니다.
class ImageDataset(Dataset):
    def __init__(self, csv, path, transform=None):
        self.df = pd.read_csv(csv).values
        self.path = path
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        name, target = self.df[idx]
        img = np.array(Image.open(os.path.join(self.path, name)))
        if self.transform:
            img = self.transform(image=img)['image']
        return img, target

# %%
# one epoch 학습을 위한 함수입니다.
def train_one_epoch(loader, model, optimizer, loss_fn, device):
    model.train()
    train_loss = 0
    preds_list = []
    targets_list = []

    pbar = tqdm(loader)
    for image, targets in pbar:
        image = image.to(device)
        targets = targets.to(device)

        model.zero_grad(set_to_none=True)

        preds = model(image)
        loss = loss_fn(preds, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        preds_list.extend(preds.argmax(dim=1).detach().cpu().numpy())
        targets_list.extend(targets.detach().cpu().numpy())

        pbar.set_description(f"Loss: {loss.item():.4f}")

    train_loss /= len(loader)
    train_acc = accuracy_score(targets_list, preds_list)
    train_f1 = f1_score(targets_list, preds_list, average='macro')

    ret = {
        "train_loss": train_loss,
        "train_acc": train_acc,
        "train_f1": train_f1,
    }

    return ret

# %% [markdown]
# ## 3. Hyper-parameters
# * 학습 및 추론에 필요한 하이퍼파라미터들을 정의합니다.

# %%
# device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# data config
data_path = 'datasets_fin/'

# model config
model_name = 'resnet34' # 'resnet50' 'efficientnet-b0', ...

# training config
img_size = 32
LR = 1e-3
EPOCHS = 1
BATCH_SIZE = 32
num_workers = 0

# ===== W&B INIT =====
wandb.init(
    project="upstage-doccls",
    name=f"baseline_{model_name}_{img_size}_bs{BATCH_SIZE}_lr{LR}",
    config={
        "model_name": model_name,
        "img_size": img_size,
        "lr": LR,
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
    }
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /data/ephemeral/home/.netrc.
# wandb: Currently logged in as: icicle424 (icicle424-home) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/root/ai-22-cv-cv-team2/baseline/wandb/run-20260223_045525-0pkfby8p</code>
# Syncing run <strong><a href='https://wandb.ai/icicle424-home/upstage-doccls/runs/0pkfby8p' target="_blank">baseline_resnet34_32_bs32_lr0.001</a></strong> to <a href='https://wandb.ai/icicle424-home/upstage-doccls' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/icicle424-home/upstage-doccls' target="_blank">https://wandb.ai/icicle424-home/upstage-doccls</a>
#  View run at <a href='https://wandb.ai/icicle424-home/upstage-doccls/runs/0pkfby8p' target="_blank">https://wandb.ai/icicle424-home/upstage-doccls/runs/0pkfby8p</a>
# &lt;wandb.sdk.wandb_run.Run object at 0x7f386f4b0c40&gt;

# %% [markdown]
# ## 4. Load Data
# * 학습, 테스트 데이터셋과 로더를 정의합니다.

# %%
# augmentation을 위한 transform 코드
trn_transform = A.Compose([
    # 이미지 크기 조정
    A.Resize(height=img_size, width=img_size),
    # images normalization
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    # numpy 이미지나 PIL 이미지를 PyTorch 텐서로 변환
    ToTensorV2(),
])

# test image 변환을 위한 transform 코드
tst_transform = A.Compose([
    A.Resize(height=img_size, width=img_size),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
DATA_ROOT = "../data"

trn_dataset = ImageDataset(
    f"{DATA_ROOT}/train.csv",
    f"{DATA_ROOT}/train/",
    transform=trn_transform
)

tst_dataset = ImageDataset(
    f"{DATA_ROOT}/sample_submission.csv",
    f"{DATA_ROOT}/test/",
    transform=tst_transform
)

print(len(trn_dataset), len(tst_dataset))
# Out:
# 1570 3140

# %%
# DataLoader 정의
trn_loader = DataLoader(
    trn_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=True,
    drop_last=False
)
tst_loader = DataLoader(
    tst_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %% [markdown]
# ## 5. Train Model
# * 모델을 로드하고, 학습을 진행합니다.

# %%
# load model
model = timm.create_model(
    model_name,
    pretrained=True,
    num_classes=17
).to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=LR)

# %%
for epoch in range(EPOCHS):
    ret = train_one_epoch(trn_loader, model, optimizer, loss_fn, device=device)
    ret['epoch'] = epoch

    log = ""
    for k, v in ret.items():
      log += f"{k}: {v:.4f}\n"
    print(log)
    wandb.log(ret)
# Out:
# Loss: 2.7266: 100%|██████████| 50/50 [00:03<00:00, 15.60it/s]
# train_loss: 2.4702
# train_acc: 0.2752
# train_f1: 0.2389
# epoch: 0.0000

# %% [markdown]
# # 6. Inference & Save File
# * 테스트 이미지에 대한 추론을 진행하고, 결과 파일을 저장합니다.

# %%
preds_list = []

model.eval()
for image, _ in tqdm(tst_loader):
    image = image.to(device)

    with torch.no_grad():
        preds = model(image)
    preds_list.extend(preds.argmax(dim=1).detach().cpu().numpy())
# Out:
# 100%|██████████| 99/99 [00:05<00:00, 19.16it/s]

# %%
pred_df = pd.DataFrame(tst_dataset.df, columns=['ID', 'target'])
pred_df['target'] = preds_list

# %%
sample_submission_df = pd.read_csv("../data/sample_submission.csv")
assert (sample_submission_df['ID'] == pred_df['ID']).all()

# %%
pred_df.to_csv("pred.csv", index=False)

# %%
pred_df.head()
# Out:
#                      ID  target
# 0  0008fdb22ddce0ce.jpg       0
# 1  00091bffdffd83de.jpg      12
# 2  00396fbc1f6cc21d.jpg      16
# 3  00471f8038d9c4b6.jpg       0
# 4  00901f504008d884.jpg      16

# %%
artifact = wandb.Artifact("submission", type="prediction")
artifact.add_file("pred.csv")
wandb.log_artifact(artifact)

wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>train_acc</td><td>▁</td></tr><tr><td>train_f1</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>train_acc</td><td>0.27516</td></tr><tr><td>train_f1</td><td>0.23891</td></tr><tr><td>train_loss</td><td>2.47016</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">baseline_resnet34_32_bs32_lr0.001</strong> at: <a href='https://wandb.ai/icicle424-home/upstage-doccls/runs/0pkfby8p' target="_blank">https://wandb.ai/icicle424-home/upstage-doccls/runs/0pkfby8p</a><br> View project at: <a href='https://wandb.ai/icicle424-home/upstage-doccls' target="_blank">https://wandb.ai/icicle424-home/upstage-doccls</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260223_045525-0pkfby8p/logs</code>
